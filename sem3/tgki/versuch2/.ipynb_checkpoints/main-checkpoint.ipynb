# %% [markdown]
# # Versuch 2

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from skimage.color import rgb2gray

# %% [markdown]
# ## Aufgabe 1

# %% [markdown]
# ### Zuerst Das Bild einlesen, croppen dessen Graustufen isolieren und deren Mittelwerte und Standardabweichungen berechnen.

# %%
img = cv2.imread("./versuch2-1_2.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

h, w = gray.shape
step = w // 5
# TODO: Fixe Fenster, damit nicht der Rand von der vorherigen Graustufe in der nächsten ist,.

cropped_imgs = [cv2.imread(f"./stufen_corrected/stufe_{i}.png") for i in range(1, 6)]
print("Cropped imgs:", cropped_imgs)
means = [np.mean(i) for i in cropped_imgs]
stds = [np.std(i) for i in cropped_imgs]
print(f"Mittelwerte: {means}\nStandardabweichungen: {stds}")
# Out:
# Cropped imgs: [array([[[31, 38, 37],
#         [30, 36, 38],
#         [30, 36, 40],
#         ...,
#         [35, 41, 48],
#         [37, 42, 48],
#         [35, 40, 44]],
#
#        [[31, 37, 41],
#         [29, 34, 39],
#         [30, 33, 39],
#         ...,
#         [36, 41, 40],
#         [37, 42, 39],
#         [35, 43, 37]],
#
#        [[31, 37, 41],
#         [30, 33, 37],
#         [33, 34, 39],
#         ...,
#         [37, 42, 39],
#         [37, 42, 37],
#         [35, 43, 37]],
#
#        ...,
#
#        [[39, 37, 37],
#         [36, 35, 35],
#         [36, 36, 36],
#         ...,
#         [32, 35, 35],
#         [34, 36, 36],
#         [35, 36, 36]],
#
#        [[36, 36, 36],
#         [36, 36, 36],
#         [37, 37, 37],
#         ...,
#         [32, 35, 35],
#         [36, 36, 36],
#         [37, 36, 36]],
#
#        [[31, 34, 40],
#         [33, 35, 40],
#         [35, 37, 39],
#         ...,
#         [33, 37, 38],
#         [34, 36, 38],
#         [35, 36, 37]]], shape=(452, 104, 3), dtype=uint8), array([[[ 78,  78,  78],
#         [ 78,  78,  78],
#         [ 79,  79,  79],
#         ...,
#         [ 83,  82,  84],
#         [ 82,  81,  82],
#         [ 82,  82,  82]],
#
#        [[ 78,  77,  80],
#         [ 76,  77,  78],
#         [ 75,  77,  77],
#         ...,
#         [ 82,  81,  83],
#         [ 83,  82,  83],
#         [ 82,  82,  82]],
#
#        [[ 79,  78,  83],
#         [ 75,  76,  80],
#         [ 71,  75,  79],
#         ...,
#         [ 80,  80,  82],
#         [ 81,  81,  82],
#         [ 82,  82,  82]],
#
#        ...,
#
#        [[ 73,  73,  75],
#         [ 71,  71,  72],
#         [ 70,  70,  70],
#         ...,
#         [ 73,  72,  79],
#         [ 75,  74,  81],
#         [ 72,  73,  80]],
#
#        [[ 71,  72,  79],
#         [ 71,  72,  75],
#         [ 72,  72,  72],
#         ...,
#         [ 77,  75,  84],
#         [ 73,  71,  81],
#         [ 71,  69,  78]],
#
#        [[ 70,  70,  79],
#         [ 70,  70,  76],
#         [ 73,  73,  75],
#         ...,
#         [102, 100, 100],
#         [100,  99,  99],
#         [ 98,  98,  98]]], shape=(457, 121, 3), dtype=uint8), array([[[127, 127, 127],
#         [127, 126, 126],
#         [127, 124, 125],
#         ...,
#         [122, 122, 122],
#         [123, 123, 123],
#         [123, 123, 123]],
#
#        [[123, 123, 123],
#         [123, 123, 123],
#         [123, 123, 123],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        [[122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122],
#         ...,
#         [122, 122, 122],
#         [122, 122, 122],
#         [122, 122, 122]],
#
#        ...,
#
#        [[ 77,  78,  83],
#         [ 79,  81,  86],
#         [ 98,  99, 104],
#         ...,
#         [114, 114, 114],
#         [114, 114, 114],
#         [114, 114, 114]],
#
#        [[ 77,  78,  85],
#         [ 80,  81,  88],
#         [ 97,  98, 104],
#         ...,
#         [115, 115, 115],
#         [114, 114, 114],
#         [114, 114, 114]],
#
#        [[ 80,  80,  82],
#         [ 82,  81,  84],
#         [ 98,  97, 100],
#         ...,
#         [115, 115, 115],
#         [114, 114, 114],
#         [114, 114, 114]]], shape=(462, 128, 3), dtype=uint8), array([[[166, 165, 165],
#         [165, 165, 165],
#         [165, 165, 165],
#         ...,
#         [164, 163, 163],
#         [166, 164, 164],
#         [167, 164, 164]],
#
#        [[167, 166, 166],
#         [168, 168, 168],
#         [167, 168, 168],
#         ...,
#         [163, 163, 163],
#         [164, 164, 164],
#         [165, 165, 165]],
#
#        [[171, 168, 167],
#         [170, 167, 168],
#         [171, 167, 168],
#         ...,
#         [164, 164, 164],
#         [165, 165, 165],
#         [164, 164, 164]],
#
#        ...,
#
#        [[156, 156, 156],
#         [156, 156, 156],
#         [156, 156, 156],
#         ...,
#         [154, 153, 155],
#         [154, 153, 155],
#         [153, 152, 154]],
#
#        [[156, 156, 156],
#         [156, 156, 156],
#         [155, 155, 155],
#         ...,
#         [151, 152, 154],
#         [153, 152, 154],
#         [153, 152, 154]],
#
#        [[156, 156, 156],
#         [155, 155, 155],
#         [156, 156, 156],
#         ...,
#         [154, 153, 156],
#         [153, 152, 154],
#         [153, 152, 153]]], shape=(458, 117, 3), dtype=uint8), array([[[215, 215, 215],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [211, 211, 215],
#         [210, 208, 213],
#         [210, 208, 213]],
#
#        [[215, 215, 215],
#         [214, 214, 214],
#         [214, 214, 214],
#         ...,
#         [212, 211, 215],
#         [211, 210, 213],
#         [211, 210, 212]],
#
#        [[214, 214, 214],
#         [215, 215, 215],
#         [215, 215, 215],
#         ...,
#         [211, 211, 215],
#         [211, 210, 213],
#         [211, 210, 212]],
#
#        ...,
#
#        [[200, 200, 202],
#         [201, 201, 201],
#         [201, 201, 201],
#         ...,
#         [198, 199, 205],
#         [199, 201, 205],
#         [199, 201, 205]],
#
#        [[200, 200, 202],
#         [200, 200, 200],
#         [199, 199, 199],
#         ...,
#         [198, 199, 207],
#         [199, 199, 209],
#         [199, 199, 209]],
#
#        [[201, 201, 201],
#         [201, 201, 201],
#         [200, 200, 200],
#         ...,
#         [199, 198, 207],
#         [199, 199, 209],
#         [199, 199, 209]]], shape=(461, 111, 3), dtype=uint8)]
# Mittelwerte: [np.float64(32.158802756977536), np.float64(73.76886027572321), np.float64(117.94189664502164), np.float64(160.36573607534305), np.float64(209.72855067648993)]
# Standardabweichungen: [np.float64(4.287599973346141), np.float64(3.94088242276356), np.float64(3.56076391729969), np.float64(3.469677794963058), np.float64(4.09150053337636)]

# %% [markdown]
# ### Die isolierten Graustufen als Bilder dargestellt.

# %%
for i, c in enumerate(cropped_imgs):
    cv2.imshow(f"Stufe {i+1}", c)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Aufgabe 2

# %% [markdown]
# ### Alle Schwarzbilder einlesen und sie in Graubilder übersetzen.

# %%
imgs = [cv2.imread(f"./versuch2-2_{i}.png") for i in range(1,11)]
gray = [cv2.cvtColor(i, cv2.COLOR_BGR2GRAY) for i in imgs]
gray = np.float64(gray)
print(gray)
# Out:
# [[[132. 131. 131. ... 126. 128. 128.]
#   [132. 131. 131. ... 126. 128. 128.]
#   [133. 132. 131. ... 126. 128. 128.]
#   ...
#   [127. 127. 127. ... 124. 123. 123.]
#   [126. 126. 128. ... 121. 119. 119.]
#   [125. 124. 124. ... 120. 122. 122.]]
#
#  [[131. 128. 129. ... 124. 123. 123.]
#   [128. 129. 130. ... 125. 125. 125.]
#   [128. 127. 127. ... 127. 127. 127.]
#   ...
#   [125. 126. 125. ... 122. 122. 122.]
#   [125. 126. 126. ... 118. 119. 119.]
#   [123. 126. 124. ... 118. 119. 119.]]
#
#  [[130. 127. 128. ... 125. 125. 125.]
#   [130. 129. 127. ... 126. 127. 127.]
#   [128. 130. 128. ... 127. 127. 127.]
#   ...
#   [123. 123. 124. ... 119. 118. 118.]
#   [125. 125. 125. ... 117. 119. 119.]
#   [125. 126. 127. ... 120. 121. 121.]]
#
#  ...
#
#  [[128. 128. 126. ... 126. 126. 126.]
#   [128. 127. 127. ... 123. 126. 126.]
#   [129. 130. 130. ... 125. 127. 127.]
#   ...
#   [126. 126. 124. ... 121. 120. 120.]
#   [127. 126. 124. ... 120. 120. 120.]
#   [126. 127. 125. ... 119. 124. 124.]]
#
#  [[130. 129. 128. ... 127. 127. 127.]
#   [129. 128. 129. ... 127. 126. 126.]
#   [128. 129. 127. ... 127. 127. 127.]
#   ...
#   [126. 125. 126. ... 123. 122. 123.]
#   [122. 125. 124. ... 122. 120. 121.]
#   [122. 125. 126. ... 123. 123. 123.]]
#
#  [[131. 130. 131. ... 125. 128. 127.]
#   [131. 129. 130. ... 125. 128. 128.]
#   [129. 129. 128. ... 127. 128. 128.]
#   ...
#   [124. 126. 126. ... 120. 120. 120.]
#   [123. 126. 125. ... 120. 119. 119.]
#   [122. 124. 126. ... 120. 119. 119.]]]

# %% [markdown]
# ### Alle pixelweisen Mittelwerte berechnen und und daraus ein "Bild von Mittelwerten" erstellen.

# %%
means_mean = np.mean(means)
means_max_contrast = cv2.normalize(means_mean, None, 0, 255, cv2.NORM_MINMAX)

cv2.imwrite("./versuch2-2_means_kontrastmaximiert.png", means_max_contrast)
# Out:
# True

# %% [markdown]
# ### Liest Dunkelbild ein, subtahiert von einem Eingabebild und gibt das korrigierte Bild aus.

# %%
# img: Eingabebild, src: Quellpfad des Dunkelbildes
def sub_from_img(src, img):
    d_src = cv2.imread(src)
    img = np.float64(img)
    mean = np.mean(img)
    means_mean = np.mean(mean)
    means_norm = means / means_mean # Mittelwert Kontrastmaximierung := 1
    print(means_norm)
    
    return img - d_src

# %% [markdown]
# ## Aufgabe 3

# %% [markdown]
# ### 10 Weißbilder einlesen, ihren Mittelwert berechnen, und davon das Dunkelbild berechnen.

# %%
imgs = [cv2.imread(f"./versuch2-3_{i}.png") for i in range(1,11)]

means_imgs = np.mean(imgs, axis=0)
#means_max_contrast = cv2.normalize(means, None, 0, 255, cv2.NORM_MINMAX)
#print(f"Mittelwert der 10 Weißbilder: {means_imgs}")
corr_img = sub_from_img("./dark.png", means_max_contrast)
print(f"Korrigiertes Bild: \n{corr_img}")
cv2.imwrite("./versuch2-3_kontrastmaximiert.png", corr_img)
div = corr_img / means_imgs
print(div)
cv2.imwrite("./versuch2-3_dividiert.png", div)
# Out:
# [0.50445181 1.15715859 1.85006897 2.51554096 3.28985962]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       3 means_imgs = np.mean(imgs, axis=0)
#       4 #means_max_contrast = cv2.normalize(means, None, 0, 255, cv2.NORM_MINMAX)
#       5 #print(f"Mittelwert der 10 Weißbilder: {means_imgs}")
# ----> 6 corr_img = sub_from_img("./dark.png", means_max_contrast)
#       7 print(f"Korrigiertes Bild: \n{corr_img}")
#       8 cv2.imwrite("./versuch2-3_kontrastmaximiert.png", corr_img)
#
# Cell In[7], line 10, in sub_from_img(src, img)
#       7 means_norm = means / means_mean # Mittelwert Kontrastmaximierung := 1
#       8 print(means_norm)
# ---> 10 return img - d_src
#
# ValueError: operands could not be broadcast together with shapes (4,1) (480,640,3)

# %% [markdown]
# ### Darstellung des kontrastmaximierten Bildes.
# <img src="./versuch2-3_kontrastmaximiert.png" />

# %% [markdown]
# ## Aufgabe 4

# %%
dark = cv2.imread("dark.png", cv2.IMREAD_GRAYSCALE)
white = cv2.imread("versuch2-3_1.png", cv2.IMREAD_GRAYSCALE)

# Hot/Stuck Pixels: deutlich heller als der Rest
hot = dark > (np.mean(dark) + 5 * np.std(dark))

# Dead Pixels: deutlich dunkler als der Rest
dead = white < (np.mean(white) - 5 * np.std(white))

print("Hot pixels:", np.argwhere(hot))
print("Dead pixels:", np.argwhere(dead))
# Out:
# Hot pixels: [[  0 544]]
# Dead pixels: []

# %% [markdown]
# ### Durch obiges kann man sehen, dass es keine Dead Pixels auf dem Weißbild gibt und nur einen Hot Pixel auf dem Dunkelbild. Die markierte Stelle des Dunkelbildes ist unten vorzufinden.
#
# <img src="./dark_stretched_markiert.png" />

# %%
img = cv2.imread("./versuch2-1_2.png")
corr = sub_from_img("./dark.png", img)
cv2.imwrite("./versuch4.png", corr)
print(corr)
# Out:
# [[[1.10806617 1.06477514 1.0997764 ]
#   [1.07951251 1.05740645 1.09424988]
#   [1.0546432  1.05372211 1.0933288 ]
#   ...
#   [1.01872085 1.0353004  1.05740645]
#   [1.01411542 1.04266908 1.06201188]
#   [1.01227325 1.04266908 1.06385405]]
#
#  [[1.08964446 1.06661731 1.0933288 ]
#   [1.07214383 1.0610908  1.09701314]
#   [1.05556428 1.06016971 1.10161857]
#   ...
#   [1.02608954 1.04082691 1.04635343]
#   [1.03253714 1.05003777 1.05832754]
#   [1.03253714 1.05003777 1.05832754]]
#
#  [[1.06385405 1.06293297 1.09517097]
#   [1.05187994 1.06477514 1.10161857]
#   [1.03806365 1.06385405 1.10346074]
#   ...
#   [1.04451125 1.04543234 1.05832754]
#   [1.05095885 1.05556428 1.06385405]
#   [1.05095885 1.05556428 1.06385405]]
#
#  ...
#
#  [[1.0353004  1.03806365 1.05924863]
#   [1.03161605 1.0353004  1.06845948]
#   [1.02332628 1.02977388 1.07214383]
#   ...
#   [1.01595759 1.00306239 1.01411542]
#   [1.01503651 1.00122022 1.01135217]
#   [1.01779977 1.00122022 1.01135217]]
#
#  [[1.04082691 1.0288528  1.05556428]
#   [1.03622148 1.03253714 1.06477514]
#   [1.02332628 1.02608954 1.06845948]
#   ...
#   [1.00029914 0.99200937 0.99937805]
#   [0.99753588 0.99108828 0.99845697]
#   [0.99753588 0.99108828 0.99937805]]
#
#  [[1.03806365 1.02332628 1.06477514]
#   [1.03898474 1.03161605 1.07306491]
#   [1.02977388 1.02977388 1.07214383]
#   ...
#   [1.00214131 0.99293045 1.00306239]
#   [1.01043108 1.00398348 1.01043108]
#   [1.01043108 1.00306239 1.01043108]]]
# [[[201. 204. 210.]
#   [198. 202. 211.]
#   [197. 202. 213.]
#   ...
#   [206. 207. 210.]
#   [204. 206. 208.]
#   [204. 206. 208.]]
#
#  [[202. 202. 209.]
#   [203. 202. 211.]
#   [204. 201. 213.]
#   ...
#   [209. 207. 212.]
#   [210. 208. 213.]
#   [210. 208. 213.]]
#
#  [[204. 205. 211.]
#   [205. 204. 212.]
#   [205. 203. 212.]
#   ...
#   [208. 209. 213.]
#   [211. 210. 213.]
#   [211. 210. 212.]]
#
#  ...
#
#  [[212. 212. 212.]
#   [212. 212. 212.]
#   [212. 212. 212.]
#   ...
#   [206. 198. 206.]
#   [207. 198. 206.]
#   [207. 198. 206.]]
#
#  [[207. 203. 210.]
#   [207. 204. 211.]
#   [205. 203. 210.]
#   ...
#   [204. 197. 204.]
#   [208. 197. 204.]
#   [208. 197. 205.]]
#
#  [[208. 206. 217.]
#   [209. 206. 216.]
#   [211. 206. 216.]
#   ...
#   [203. 198. 203.]
#   [204. 196. 202.]
#   [205. 196. 202.]]]

# %% [markdown]
# ### Korrigiertes Bild des Grauwertkeils.
#
# <img src="./versuch4.png">

# %%
cropped_imgs = []
for i in range(5):
    start = i * step
    end = (i + 1) * step
    cropped_imgs.append(corr[:, start:end])
print("Cropped imgs:", cropped_imgs)
means = [np.mean(i) for i in cropped_imgs]
stds = [np.std(i) for i in cropped_imgs]
print(f"Mittelwerte: {means}\nStandardabweichungen: {stds}")

print("Image Matrix:")
df = pd.DataFrame({
    "Stufe": range(1, 6),
    "Mittelwert": means,
    "Standardabweichung": stds
})

print(df)
# Out:
# Cropped imgs: [array([[[201., 204., 210.],
#         [198., 202., 211.],
#         [197., 202., 213.],
#         ...,
#         [212., 211., 214.],
#         [212., 211., 214.],
#         [211., 210., 213.]],
#
#        [[202., 202., 209.],
#         [203., 202., 211.],
#         [204., 201., 213.],
#         ...,
#         [212., 212., 213.],
#         [212., 212., 212.],
#         [212., 212., 213.]],
#
#        [[204., 205., 211.],
#         [205., 204., 212.],
#         [205., 203., 212.],
#         ...,
#         [213., 211., 214.],
#         [212., 211., 214.],
#         [212., 211., 214.]],
#
#        ...,
#
#        [[212., 212., 212.],
#         [212., 212., 212.],
#         [212., 212., 212.],
#         ...,
#         [200., 200., 200.],
#         [203., 203., 203.],
#         [204., 204., 204.]],
#
#        [[207., 203., 210.],
#         [207., 204., 211.],
#         [205., 203., 210.],
#         ...,
#         [209., 203., 206.],
#         [210., 202., 207.],
#         [210., 202., 207.]],
#
#        [[208., 206., 217.],
#         [209., 206., 216.],
#         [211., 206., 216.],
#         ...,
#         [205., 204., 210.],
#         [206., 204., 211.],
#         [208., 203., 211.]]], shape=(480, 128, 3)), array([[[210., 209., 211.],
#         [210., 209., 211.],
#         [208., 208., 210.],
#         ...,
#         [215., 214., 214.],
#         [214., 214., 214.],
#         [212., 212., 212.]],
#
#        [[211., 210., 213.],
#         [210., 209., 211.],
#         [210., 209., 211.],
#         ...,
#         [215., 213., 213.],
#         [215., 213., 213.],
#         [214., 213., 213.]],
#
#        [[212., 211., 214.],
#         [212., 211., 213.],
#         [211., 210., 213.],
#         ...,
#         [219., 214., 214.],
#         [218., 214., 214.],
#         [219., 215., 215.]],
#
#        ...,
#
#        [[204., 204., 204.],
#         [202., 201., 201.],
#         [204., 201., 201.],
#         ...,
#         [204., 203., 206.],
#         [204., 203., 206.],
#         [204., 203., 206.]],
#
#        [[210., 203., 206.],
#         [210., 203., 205.],
#         [209., 202., 203.],
#         ...,
#         [206., 204., 204.],
#         [206., 204., 204.],
#         [206., 204., 204.]],
#
#        [[210., 202., 209.],
#         [210., 202., 207.],
#         [210., 203., 206.],
#         ...,
#         [205., 203., 205.],
#         [206., 203., 206.],
#         [206., 203., 205.]]], shape=(480, 128, 3)), array([[[212., 212., 212.],
#         [212., 212., 212.],
#         [212., 212., 212.],
#         ...,
#         [219., 216., 217.],
#         [217., 215., 215.],
#         [216., 215., 215.]],
#
#        [[213., 213., 213.],
#         [212., 212., 212.],
#         [213., 213., 213.],
#         ...,
#         [221., 217., 218.],
#         [217., 215., 215.],
#         [217., 215., 215.]],
#
#        [[220., 215., 215.],
#         [218., 214., 214.],
#         [218., 214., 214.],
#         ...,
#         [223., 216., 217.],
#         [223., 216., 217.],
#         [220., 215., 215.]],
#
#        ...,
#
#        [[204., 203., 206.],
#         [202., 202., 203.],
#         [203., 203., 203.],
#         ...,
#         [206., 204., 204.],
#         [206., 204., 204.],
#         [206., 204., 204.]],
#
#        [[206., 204., 204.],
#         [205., 202., 203.],
#         [205., 202., 203.],
#         ...,
#         [209., 203., 204.],
#         [208., 203., 204.],
#         [208., 203., 204.]],
#
#        [[206., 204., 204.],
#         [206., 204., 204.],
#         [206., 204., 204.],
#         ...,
#         [204., 204., 204.],
#         [203., 203., 203.],
#         [203., 203., 202.]]], shape=(480, 128, 3)), array([[[215., 215., 215.],
#         [216., 217., 217.],
#         [217., 217., 217.],
#         ...,
#         [212., 212., 212.],
#         [212., 212., 212.],
#         [212., 212., 213.]],
#
#        [[217., 215., 215.],
#         [218., 215., 215.],
#         [219., 216., 217.],
#         ...,
#         [213., 213., 213.],
#         [212., 212., 212.],
#         [213., 213., 214.]],
#
#        [[219., 216., 217.],
#         [217., 215., 215.],
#         [219., 216., 217.],
#         ...,
#         [214., 214., 216.],
#         [214., 214., 216.],
#         [215., 215., 216.]],
#
#        ...,
#
#        [[206., 204., 204.],
#         [205., 204., 204.],
#         [204., 204., 204.],
#         ...,
#         [204., 200., 204.],
#         [204., 200., 205.],
#         [205., 200., 205.]],
#
#        [[207., 202., 203.],
#         [206., 204., 204.],
#         [204., 204., 204.],
#         ...,
#         [201., 199., 199.],
#         [201., 199., 199.],
#         [201., 199., 199.]],
#
#        [[203., 203., 203.],
#         [204., 203., 205.],
#         [205., 204., 207.],
#         ...,
#         [198., 198., 198.],
#         [198., 198., 198.],
#         [198., 198., 198.]]], shape=(480, 128, 3)), array([[[212., 211., 214.],
#         [212., 211., 214.],
#         [213., 213., 215.],
#         ...,
#         [206., 207., 210.],
#         [204., 206., 208.],
#         [204., 206., 208.]],
#
#        [[213., 213., 215.],
#         [212., 212., 213.],
#         [213., 213., 213.],
#         ...,
#         [209., 207., 212.],
#         [210., 208., 213.],
#         [210., 208., 213.]],
#
#        [[214., 214., 214.],
#         [214., 214., 214.],
#         [214., 214., 214.],
#         ...,
#         [208., 209., 213.],
#         [211., 210., 213.],
#         [211., 210., 212.]],
#
#        ...,
#
#        [[204., 199., 204.],
#         [201., 198., 202.],
#         [199., 199., 201.],
#         ...,
#         [206., 198., 206.],
#         [207., 198., 206.],
#         [207., 198., 206.]],
#
#        [[202., 200., 200.],
#         [200., 198., 198.],
#         [200., 198., 198.],
#         ...,
#         [204., 197., 204.],
#         [208., 197., 204.],
#         [208., 197., 205.]],
#
#        [[199., 199., 199.],
#         [200., 199., 199.],
#         [201., 199., 199.],
#         ...,
#         [203., 198., 203.],
#         [204., 196., 202.],
#         [205., 196., 202.]]], shape=(480, 128, 3))]
# Mittelwerte: [np.float64(39.834705946180556), np.float64(78.28073459201389), np.float64(120.72434895833334), np.float64(159.44680989583333), np.float64(204.86615125868056)]
# Standardabweichungen: [np.float64(30.65910683912118), np.float64(23.252531502870216), np.float64(15.90280003821061), np.float64(13.281739068654328), np.float64(15.1883181681383)]
# Image Matrix:
#    Stufe  Mittelwert  Standardabweichung
# 0      1   39.834706           30.659107
# 1      2   78.280735           23.252532
# 2      3  120.724349           15.902800
# 3      4  159.446810           13.281739
# 4      5  204.866151           15.188318
