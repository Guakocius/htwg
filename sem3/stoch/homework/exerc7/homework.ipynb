# %% [markdown]
# # Homework 7 - Übungsblätter 5 und 6

# %%
from scipy.stats import binom, geom, poisson, uniform, expon, norm
from scipy.integrate import quad
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Markdown

# %% [markdown]
# ## Aufgabe 5.11

# %%
p1 = 0.007 # 7-Tage-Inzidenz von 700
incidence = 700
N = 1000
sensitivity = 0.85 # richtig-positiv
specificity = 0.99 # richtig-negativ
p2 =

# %% [markdown]
# ### b)
# $$X_1 \sim Binom(1000, 0.007)\\ X_2 \sim Po(0.7)$$

# %% [markdown]
# ## Aufgabe 6.5
# ### Teilaufgabe 6.5.1

# %% [markdown]
# $$1 = \int_{150}^{750} k \,dx = [k]^{750}_{150} = 750k - 150k = 600k \rightarrow k = \dfrac{1}{600}$$

# %%
# a)
p = 0.002
M1 = uniform(loc=150, scale=500)
pa = M1.cdf(500)
print(pa)
pb = 1 - (M1.cdf(250) + M1.sf(350))
mean = M1.mean()
std = M1.std()
print(pb)
print("Erwartungswert: {}\tStandardabweichung: {:.3f}".format(mean,std))
# Out:
# 0.7
# 0.19999999999999996
# Erwartungswert: 400.0	Standardabweichung: 144.338

# %% [markdown]
# ### Teilaufgabe 6.5.2

# %%
T1 = expon(scale=1/4)
# a)
pa = T1.sf(0.5)
t_zub = T1.ppf(0.75)
mean = T1.mean()
std = T1.std()
print(f"{pa:.3f}")
print(f"{t_zub:.3f}")
print(mean)
print(std)
# Out:
# 0.135
# 0.347
# 0.25
# 0.25

# %% [markdown]
# ## Aufgabe 6.6

# %%
std = 100
var = std**2
mean = 300
M2 = norm(mean,std)

display(Markdown(f"$$M_2 \sim Norm({mean}, {var})$$"))

pb = M2.cdf(350)
print(pb)
pc = M2.sf(200)
print(pc)
display(Markdown("#### d) genau 300 ml = 0"))
pe = M2.ppf(0.95)
print(pe)
# Out:
# $$M_2 \sim Norm(300, 10000)$$
# 0.6914624612740131
# 0.8413447460685429
# #### d) genau 300 ml = 0
# 464.4853626951472

# %% [markdown]
# ##

# %% [markdown]
# ## Aufgabe 6.13

# %% [markdown]
# ### a)
# P(5 <= F1 <= 20) = P(F1 <= 20) - P(F1 <= 5)

# %%
#F1 = exp(1/7)
#F2 = uniform(loc=70,scale=80)
#F3 = n

# %% [markdown]
# ## Aufgabe 6.14
# ### Teilaufgabe 6.14.1

# %%
A = uniform(loc=100, scale=400)
B = expon(scale=1/4)
c_mean, c_std = -5, 2
C = norm(c_mean, c_std)
pa = C.cdf(-4)
print(pa)
display(Markdown("#### b) exakt -5 = 0"))
pc = C.ppf(0.95)
print(pc)
display(Markdown("#### b)\n $$99.7\% = 3\sigma; I := [\mu-3\sigma; \mu+3\sigma]$$"))
pd = (c_mean-3*c_std, c_mean+3*c_std)
print(pd)
# Out:
# 0.6914624612740131
# #### b) exakt -5 = 0
# -1.7102927460970556
# #### b)
#  $$99.7\% = 3\sigma; I := [\mu-3\sigma; \mu+3\sigma]$$
# (-11, 1)

# %% [markdown]
# ### Teilaufgabe 6.14.2

# %%
pa = B.sf(0.5)
print(f"{pa:.3f}")
pb = B.cdf(1.0) - B.cdf(0.5)
print(f"{pb:.3f}")
# Out:
# 0.135
# 0.117

# %% [markdown]
# ### Teilaufgabe 6.14.3

# %%
pa = A.cdf(300)
print(pa)
pb = A.ppf(0.95)
print(pb)
# Out:
# 0.5
# 480.0

# %% [markdown]
# ### Teilaufgabe 6.14.4
