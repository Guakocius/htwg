# %% [markdown]
# # Homework 7 - Übungsblätter 5 und 6

# %% [markdown]
# ## Aufgabe 6.13

# %% [markdown]
# ### a)
# P(5 <= F1 <= 20) = P(F1 <= 20) - P(F1 <= 5)

# %%
import numpy as np, scipy.stats as stats

# %%
F1 = stats.exp(1/7)
F2 = stats.uniform(loc=70,scale=80)
F3 = stats.n
