# %%
import numpy as np
from scipy.stats import binom, poisson, geom, norm, expon, uniform
from scipy.integrate import quad
import matplotlib.pyplot as plt

# %%
fE = [[2,0.1],[3,0.3],[4,0.4],[5,0.2],[6,0.1]]
EfE = sum(norm.mean(fE[0]))
fG = lambda x : (
    0 if x < 2 else
    3/(x**2) if 2 <= x <= 6 else
    0
) # density


print(EfE)

#FG = lambda x : (
#    0 if x < 2 else
#    3/(x)
#)
# Out:
# 2.1

# %%
P = norm.pmf(3, [0.1,0.2,0.4,0.2,0.1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 P = norm.pmf(3, [0.1,0.2,0.4,0.2,0.1])
#
# AttributeError: 'norm_gen' object has no attribute 'pmf'

# %%
EG = quad(lambda x : fG(x), 2, 6)
print(EG)


print()
# Out:
# (0.9999999999999999, 4.359699318964988e-12)
# <generator object <genexpr> at 0x7f0e072c12f0>

# %%
p = 0.75 # wass
q = 0.25 # zerst
lam = 5
print(binom.sf(4, 10, 0.75))
print(geom.pmf(4, 0.25))
# Out:
# 0.9802722930908203
# 0.10546875
